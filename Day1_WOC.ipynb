# %%
import pandas as pd

# %%
df=pd.read_csv(r"Downloads/raw_data/raw_data/parameters_8000-10000.csv")

# %%
df.head()
# Out:
#       noise                                player_0  player_1 player_10  \
# 0  0.849486  Nice Meta Winner Ensemble: 173 players  Prober 2   Thumper
# 1  0.040484  Nice Meta Winner Ensemble: 173 players  Prober 2   Thumper
# 2  0.847434  Nice Meta Winner Ensemble: 173 players  Prober 2   Thumper
# 3  0.084872  Nice Meta Winner Ensemble: 173 players  Prober 2   Thumper
# 4  0.544229  Nice Meta Winner Ensemble: 173 players  Prober 2   Thumper
#
#                    player_100 player_101 player_102 player_103 player_104  \
# 0  Meta Minority: 173 players        NaN        NaN        NaN        NaN
# 1  Meta Minority: 173 players        NaN        NaN        NaN        NaN
# 2  Meta Minority: 173 players        NaN        NaN        NaN        NaN
# 3  Meta Minority: 173 players        NaN        NaN        NaN        NaN
# 4  Meta Minority: 173 players        NaN        NaN        NaN        NaN
#
#   player_105  ... player_95 player_96             player_97  \
# ...

# %%
df.drop(columns=[
    'player_101','player_102','player_104','player_105','player_113','player_115','player_116',
    'player_121','player_123','player_127','player_128','player_130','player_133','player_134',
    'player_136','player_138','player_14','player_144','player_145','player_146','player_148',
    'player_152','player_156','player_157','player_158','player_16','player_98','player_97',
    'player_90','player_96','player_88','player_86','player_78','player_74','player_73',
    'player_72','player_68','player_67','player_65','player_48','player_50','player_53',
    'player_54','player_55','player_57','player_58','player_161','player_165','player_166',
    'player_168','player_169','player_170','player_176','player_179','player_183','player_187',
    'player_19','player_2','player_23','player_37','player_43','player_44','player_45','player_33',
    'player_34','player_3','player_31','player_30','player_22','player_20','player_15','player_100','player_0',
    'player_80','player_8','player_82','player_83','player_87','player_89','player_92','player_93','player_94','player_99',
    'player_35','player_47','player_122','player_36','player_39','player_41','player_51',
    'player_59','player_62','player_64','player_66','player_76',
    'player_77','player_81','player_117','player_120','player_125','player_13','player_131','player_154',
    'player_167','player_172','player_24','player_21','player_28','player_29',
    'player_32','player_38','player_46','player_40','player_5','player_61',
    'player_84','player_95','player_12','player_18','player_27','player_4','player_91','seed'
],inplace=True)

# %%
df.shape
# Out:
# (182, 71)

# %%
df.sample(5)
# Out:
#         noise            player_1 player_10               player_103  \
# 172  0.480481            Prober 2   Thumper                      NaN
# 106  0.657473            Prober 2   Thumper                      NaN
# 149  0.839800  DoubleResurrection  Predator  Slow Tit For Two Tats 2
# 15   0.702586            Prober 2   Thumper                      NaN
# 167  0.856863            Prober 2   Thumper                      NaN
#
#     player_106      player_107 player_108      player_109     player_11  \
# 172        NaN             NaN        NaN             NaN  Fool Me Once
# 106        NaN             NaN        NaN             NaN  Fool Me Once
# 149    Grudger  Average Copier   Appeaser  Level Punisher         $\pi$
# 15         NaN             NaN        NaN             NaN  Fool Me Once
# 167        NaN             NaN        NaN             NaN  Fool Me Once
#
#     player_110  ...               player_70       player_71      player_75  \
# ...
